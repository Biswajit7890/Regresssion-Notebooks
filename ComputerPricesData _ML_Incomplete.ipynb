# %%
import pandas as pd
import numpy as np

# %%
ComputerPricesData =pd.read_csv('C:/Users/user/Desktop/IVY WORK BOOK/PYTHON/Python Datasets/Regression Datasets/ComputerPricesData.csv')
ComputerPricesData
# Out:
#       price  speed    hd  ram  screen   cd multi premium  ads  trend
# 0      1499     25    80    4      14   no    no     yes   94      1
# 1      1795     33    85    2      14   no    no     yes   94      1
# 2      1595     25   170    4      15   no    no     yes   94      1
# 3      1849     25   170    8      14   no    no      no   94      1
# 4      3295     33   340   16      14   no    no     yes   94      1
# ...     ...    ...   ...  ...     ...  ...   ...     ...  ...    ...
# 6254   1690    100   528    8      15   no    no     yes   39     35
# 6255   2223     66   850   16      15  yes   yes     yes   39     35
# 6256   2654    100  1200   24      15  yes    no     yes   39     35
# 6257   2195    100   850   16      15  yes    no     yes   39     35
# 6258   2490    100   850   16      17  yes    no     yes   39     35
#
# [6259 rows x 10 columns]

# %%
ComputerPricesData.drop_duplicates()
# Out:
#       price  speed    hd  ram  screen   cd multi premium  ads  trend
# 0      1499     25    80    4      14   no    no     yes   94      1
# 1      1795     33    85    2      14   no    no     yes   94      1
# 2      1595     25   170    4      15   no    no     yes   94      1
# 3      1849     25   170    8      14   no    no      no   94      1
# 4      3295     33   340   16      14   no    no     yes   94      1
# ...     ...    ...   ...  ...     ...  ...   ...     ...  ...    ...
# 6254   1690    100   528    8      15   no    no     yes   39     35
# 6255   2223     66   850   16      15  yes   yes     yes   39     35
# 6256   2654    100  1200   24      15  yes    no     yes   39     35
# 6257   2195    100   850   16      15  yes    no     yes   39     35
# 6258   2490    100   850   16      17  yes    no     yes   39     35
#
# [6183 rows x 10 columns]

# %%
ComputerPricesData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6259 entries, 0 to 6258
# Data columns (total 10 columns):
# price      6259 non-null int64
# speed      6259 non-null int64
# hd         6259 non-null int64
# ram        6259 non-null int64
# screen     6259 non-null int64
# cd         6259 non-null object
# multi      6259 non-null object
# premium    6259 non-null object
# ads        6259 non-null int64
# trend      6259 non-null int64
# dtypes: int64(7), object(3)
# memory usage: 489.1+ KB

# %%
ComputerPricesData.nunique()
# Out:
# price      808
# speed        6
# hd          59
# ram          6
# screen       3
# cd           2
# multi        2
# premium      2
# ads         34
# trend       35
# dtype: int64

# %%
ComputerPricesData['hd'].unique()
# Out:
# array([  80,   85,  170,  340,  210,  130,  245,  212,  250,  452,  500,
#         120,  330,  230,  213,  240,  320,  214,  107,  405, 1000,  540,
#         450,  345,  527,  545, 1370,  426, 1100,  424,  528,  525, 1200,
#         425, 1060,  520,  420,  125,  270,  256,  530,  260,  470,  100,
#        1080,  428, 2100,  728,  200,  720,  730,  364,  128,  810,  850,
#         365, 1260, 1600,  630], dtype=int64)

# %%
ComputerPricesData.corrwith(ComputerPricesData['price'], axis=0)
# Out:
# price     1.000000
# speed     0.299855
# hd        0.351715
# ram       0.625255
# screen    0.267898
# ads       0.096827
# trend    -0.254149
# dtype: float64

# %%
ComputerPricesData.describe(include='all')
# Out:
#               price        speed           hd          ram       screen    cd  \
# count   5727.000000  5727.000000  5727.000000  5727.000000  5727.000000  5727
# unique          NaN          NaN          NaN          NaN          NaN     2
# top             NaN          NaN          NaN          NaN          NaN    no
# freq            NaN          NaN          NaN          NaN          NaN  3234
# mean    2140.522263    51.106862   370.477039     7.419591    14.572027   NaN
# std      503.155139    20.892313   201.576093     4.522593     0.888082   NaN
# min      949.000000    25.000000    80.000000     2.000000    14.000000   NaN
# 25%     1754.000000    33.000000   214.000000     4.000000    14.000000   NaN
# 50%     2094.000000    50.000000   340.000000     8.000000    14.000000   NaN
# 75%     2495.000000    66.000000   528.000000     8.000000    15.000000   NaN
# max     3544.000000   100.000000  1200.000000    24.000000    17.000000   NaN
#
# ...

# %%
cat_cols=['speed','ram','screen','trend','ads','cd','premium']
outlier_cols =['ads']
selected_cols=['ram','hd','speed','screen','trend','ads','cd','premium','price']

# %%
ComputerPricesData.plot.scatter(x='ads', y='price', figsize=(15,6))

# %%
ComputerPricesData.groupby('trend').sum()['price'].plot(kind='bar', figsize=(15,6))

# %%
ComputerPricesData.boxplot(column='price', by='ads', figsize=(15,10))

# %%
ComputerPricesData.hist('trend', figsize=(15,4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000236D5112D48>]],
#       dtype=object)

# %%
col1=ComputerPricesData['ads']==225
col2=ComputerPricesData['price']>3550
Deleterow1=ComputerPricesData[col2].index
ComputerPricesData=ComputerPricesData.drop(Deleterow1)

# %%
ComputerPricesData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5834 entries, 0 to 6258
# Data columns (total 10 columns):
# price      5834 non-null int64
# speed      5834 non-null int64
# hd         5834 non-null int64
# ram        5834 non-null int64
# screen     5834 non-null int64
# cd         5834 non-null object
# multi      5834 non-null object
# premium    5834 non-null object
# ads        5834 non-null int64
# trend      5834 non-null int64
# dtypes: int64(7), object(3)
# memory usage: 501.4+ KB

# %%
from scipy.stats import f_oneway
for i in cat_cols:
    CategoricalAnova=ComputerPricesData.groupby(i)['price'].apply(list)
    Annovaresult=f_oneway(*CategoricalAnova)
    print("the p value of",i,"is", Annovaresult[1])
    if(Annovaresult[1]>0.05):
        print("The value of",i,"is not cooreleated with the Target variable")
    else:
        print("The value of",i,"is cooreleated with the Target variable")
# Out:
# the p value of speed is 1.976610372874709e-152
# The value of speed is cooreleated with the Target variable
# the p value of ram is 0.0
# The value of ram is cooreleated with the Target variable
# the p value of screen is 1.690116338340566e-117
# The value of screen is cooreleated with the Target variable
# the p value of trend is 2.6122882898663324e-99
# The value of trend is cooreleated with the Target variable
# the p value of ads is 6.062911878087795e-100
# The value of ads is cooreleated with the Target variable
# the p value of cd is 8.373435132105782e-30
# The value of cd is cooreleated with the Target variable
# the p value of multi is 0.206555680211781
# The value of multi is not cooreleated with the Target variable
# the p value of premium is 1.3798626685338452e-15
# The value of premium is cooreleated with the Target variable

# %%
selected_cols=['ram','hd','speed','screen','trend','cd','premium','price']
ComputerPricesData_ML=pd.DataFrame(ComputerPricesData,columns=selected_cols)
ComputerPricesData_ML.head()
ComputerPricesData_ML['screen'].unique()
ComputerPricesData_ML=pd.get_dummies(ComputerPricesData_ML)
ComputerPricesData_ML.head()
# Out:
#    ram   hd  speed  screen  trend  price  cd_no  cd_yes  premium_no  \
# 0    4   80     25      14      1   1499      1       0           0
# 1    2   85     33      14      1   1795      1       0           0
# 2    4  170     25      15      1   1595      1       0           0
# 3    8  170     25      14      1   1849      1       0           1
# 4   16  340     33      14      1   3295      1       0           0
#
#    premium_yes
# 0            1
# 1            1
# 2            1
# 3            0
# 4            1

# %%
ComputerPricesData.isnull().sum()
# Out:
# price      0
# speed      0
# hd         0
# ram        0
# screen     0
# cd         0
# multi      0
# premium    0
# ads        0
# trend      0
# dtype: int64

# %%
ComputerPricesData_ML.corrwith(ComputerPricesData_ML['price'], axis=0)
# Out:
# ram            0.625255
# hd             0.351715
# speed          0.299855
# screen         0.267898
# trend         -0.254149
# price          1.000000
# cd_no         -0.177285
# cd_yes         0.177285
# premium_no     0.074329
# premium_yes   -0.074329
# dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

import copy

# %%
ComputerPricesData_ML.columns
# Out:
# Index(['ram', 'hd', 'speed', 'screen', 'trend', 'price', 'cd_no', 'cd_yes',
#        'premium_no', 'premium_yes'],
#       dtype='object')

# %%
predictors=['ram', 'hd', 'speed', 'screen', 'trend','cd_no', 'cd_yes',
       'premium_no', 'premium_yes']
Target=['price']
X=ComputerPricesData_ML[predictors].values
y=ComputerPricesData_ML[Target].values
print(X.shape)
print(y.shape)
# Out:
# (5727, 9)
# (5727, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
mlr=LinearRegression()
predictmodel=mlr.fit(X,y)
prediction = predictmodel.predict(X_test)
print("Thr R square is",metrics.r2_score(y_train,predictmodel.predict(X_train)))
X1=sm.add_constant(X_train)
Reg=sm.OLS(y_train,X1).fit() 
print("The Adjust R square ",Reg.rsquared_adj)
print("The Accuracy of the model",100-np.mean(np.abs((y_test-prediction)/y_test)*100))
Predictedtable=pd.DataFrame(X_test, columns=predictors)
Predictedtable['price']=y_test
Predictedtable['ape']=np.abs((y_test-prediction)/y_test)*100
# Out:
# Thr R square is 0.7637454870204435
# The Adjust R square  0.763517557256316
# The Accuracy of the model 90.20917334343693

# %%
Predictedtable['ape'].hist(figsize=(15,6))

# %%
Predictedtable.boxplot('ape', figsize=(15,6), vert=False)

# %%
from sklearn.tree import DecisionTreeRegressor
dlr=DecisionTreeRegressor(max_depth=3,criterion='mse')
Decisionreg=dlr.fit(X,y)
predictiontree=Decisionreg.predict(X_test)
print(dlr)
print("The R2 square is ",metrics.r2_score(y_train,Decisionreg.predict(X_train)))
print("The Accuracy wscore is",100- (np.mean(np.abs((y_test - prediction) / y_test)) * 100))
feautersimportance =pd.Series(Decisionreg.feature_importances_,index=predictors)
feautersimportance.nlargest(10).plot(kind='barh')
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=3, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')
# The R2 square is  0.5966666215651224
# The Accuracy wscore is 90.20917334343693

# %%
from sklearn import tree
from IPython.display import Image
import pydotplus

Draw_Graph=tree.export_graphviz(Decisionreg,out_file=None,feature_names=predictors,class_names=Target)
graph=pydotplus.graph_from_dot_data(Draw_Graph)
Image(graph.create_png())

# %%
print(X.shape)
print(y.shape)
# Out:
# (6259, 2)
# (6259, 1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import copy

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.5,random_state=1879)
print('The shape of all train and test datasets')
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
mlr = LinearRegression()
ComputerRegdata_Model=mlr.fit(X_train, y_train)
print('/'*60)
print('The coeffiecent is :',ComputerRegdata_Model.coef_)
print('The  Intercept is :',ComputerRegdata_Model.intercept_)
y=y_train
Yhat=ComputerRegdata_Model.predict(X_train)
SS_Residual = sum((y_train-Yhat)**2)
SS_Total = sum((y_train-np.mean(y))**2)
r_squared = 1 - (float(SS_Residual))/SS_Total 
adjusted_r_squared = 1 - (1-r_squared)*(len(y)-1)/(len(y)-X.shape[1]-1)
print('/'*60)
print('The r squared is :',r_squared )
print('The adj r squared is :',adjusted_r_squared)
yhattesting=ComputerRegdata_Model.predict(X_test)
ComputerPricesDataTestdata=pd.DataFrame(X_test,columns=SelectedColumsForMLR)
ComputerPricesDataTestdata['price']=y_test
print('/'*60)
print(ComputerPricesDataTestdata.head())
ComputerPricesDataTestdataCopy=copy.deepcopy(ComputerPricesDataTestdata)
ComputerPricesDataTestdataCopy['predprice']=yhattesting.round(1)
print('/'*60)
print(ComputerPricesDataTestdataCopy.head())
ComputerPricesDataTestdataCopy['ape']=(abs(ComputerPricesDataTestdataCopy['price']-ComputerPricesDataTestdataCopy['predprice'])/ComputerPricesDataTestdataCopy['price'])*100
print('/'*60)
print(ComputerPricesDataTestdataCopy.head())
print('/'*60)
print('Testing data Mean Absolute Percent Error(MAPE): ',(np.mean(ComputerPricesDataTestdataCopy['ape'])), '%')
print('Testing data Average Accuracy of the model: ',100 - round((np.mean(ComputerPricesDataTestdataCopy['ape']))), '%')
#plt.scatter(x=ComputerPricesDataTestdataCopy['speed'] , y=ComputerPricesDataTestdataCopy['price'])
#plt.scatter(ComputerPricesDataTestdataCopy['speed'] , ComputerPricesDataTestdataCopy['predprice'], color='red')
# Out:
# The shape of all train and test datasets
# (3129, 2)
# (3130, 2)
# (3129, 1)
# (3130, 1)
# ////////////////////////////////////////////////////////////
# The coeffiecent is : [[62.39835578  4.1942195 ]]
# The  Intercept is : [1484.03110941]
# ////////////////////////////////////////////////////////////
# The r squared is : [0.42733296]
# The adj r squared is : [0.42696657]
# ////////////////////////////////////////////////////////////
#    ram  speed  price
# 0    8     33   2999
# 1    8    100   2495
# 2   16     33   2290
# 3    8     66   1695
# 4   16     33   2844
# ////////////////////////////////////////////////////////////
#    ram  speed  price  predprice
# 0    8     33   2999     2121.6
# 1    8    100   2495     2402.6
# 2   16     33   2290     2620.8
# 3    8     66   1695     2260.0
# 4   16     33   2844     2620.8
# ////////////////////////////////////////////////////////////
#    ram  speed  price  predprice        ape
# 0    8     33   2999     2121.6  29.256419
# ...

# %%
ComputerPricesDataTestdataCopy.hist('ape',figsize=[15,4])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002E03AE24A08>]],
#       dtype=object)

# %%
ComputerPricesDataTestdataCopy.boxplot('ape',figsize=[15,4])
